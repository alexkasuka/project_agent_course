# %% [markdown]
# # Demo Assignment\n\nCreate a LangGraph-based assignment assistant. The assistant should read course materials, search for relevant context, draft a solution, request human review, and save the final result.

# %% [markdown]
# ## Requirements\n\n- Define a typed State.\n- Implement at least three nodes: load assignment, retrieve context, draft solution.\n- Use one tool for searching course materials.\n- Add a human-in-the-loop review step.\n- Save the final homework artifact to disk.

# %%
# Optional smoke-test idea\n# result = graph.invoke({"assignment": "Create a LangGraph assignment assistant"})\n# assert result["draft_solution"]\n# assert result["review_request"]
